# %%
class CreditCard:
    def __init__(self, number, cvv, expiry):
        self.number = number
        self.cvv = cvv
        self.expiry = expiry

class User:
    def __init__(self, name):
        self.name = name
        self.cards = []  # sửa ở đây

    def add_card(self, card):
        self.cards.append(card)

    def show_cards(self):
        for i, card in enumerate(self.cards, 1):
            print(f"Thẻ {i}: {card.number} | CVV: {card.cvv} | Hết hạn: {card.expiry}")


s1 = User("Tai")

n = int(input("Nhập số thẻ: "))

for i in range(n):
    print(f"\nNhập thẻ {i+1}:")
    number = input("Số thẻ: ")
    cvv = input("CVV: ")
    expiry = input("Hạn: ")

    card = CreditCard(number, cvv, expiry)
    s1.add_card(card)

print("\nDanh sách thẻ:")
s1.show_cards()
# Out:
# Hello Don't have name

# %%
class Dog:
    __name = None
    def __init__(self, name = None):
        self.__name = name
    
    def set_name(self, name):
        self.__name = name

    def get_name(self):
        return f"Con cho cua ban ten la: {self.__name}"

myDog = Dog()
myDog.set_name("mi lu")
print(myDog.get_name())
# Out:
# Con cho cua ban ten la: mi lu

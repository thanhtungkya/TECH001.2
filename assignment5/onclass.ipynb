# %%
import re
hand = open("/Users/tungthanhdo/Documents/python/assignment5/mbox-short.txt")
for line in hand:
    line = line.strip()
    res = re.search(r'^from', line)
    #re.search('from', line)
    if res:
        print(line)

# %%
import re
content = "Vietnix cung cấp dịch vụ hosting chất lượng cao."
matchObj = re.search(r'Vietnix', content)
if matchObj:
    print(f"Chuỗi khớp bắt đầu tại vị trí {matchObj.start()} và kết thúc tại {matchObj.end()}")
    print("Nội dung khớp:", matchObj.group())
else:
    print("Không tìm thấy kết quả.")
# Out:
# Chuỗi khớp bắt đầu tại vị trí 0 và kết thúc tại 7
# Nội dung khớp: Vietnix

# %%
import re
hand = open("/Users/tungthanhdo/Documents/python/assignment5/mbox-short.txt")
numlist = list()
for line in hand:
    line = line.rstrip()
    stuff = re.findall('^X-DSPAM-Confidence: ([0-9.]+)', line)
    if len(stuff) == 1:
        num = float(stuff[0])
        numlist.append(num)

print("maximum: ", min(numlist))
# Out:
# maximum:  0.6178

# %%
jjj = {'chuck':1}
for a in jjj.items():
    print(a)
# Out:
# ('chuck', 1)
